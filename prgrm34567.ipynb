# %%
from PIL import Image
img=Image.open('plant1.jpg')
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CENTRA~1\AppData\Local\Temp/ipykernel_6444/914988602.py in <module>
#       3 img=img.rotate(180)
#       4 img.show()
# ----> 5 cv2.waitKey(0)
#       6 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("red")
print(img2)
# Out:
# (255, 255, 0)
# (255, 0, 0)

# %%
from PIL import Image
img=Image.new("RGB",(300,400),(0,255,0))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('butterfly1.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtcolor(img.cv2.COLOR_BGR2RGB)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\CENTRA~1\AppData\Local\Temp/ipykernel_6444/802425167.py in <module>
#       5 plt.imshow(img)
#       6 plt.show()
# ----> 7 img=cv2.cvtcolor(img.cv2.COLOR_BGR2RGB)
#       8 plt.show()
#       9 img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
#
# AttributeError: module 'cv2' has no attribute 'cvtcolor'

# %%
from PIL import Image
image=Image.open('butterfly2.jpg')
print("Filename :  ",image.filename)
print("Format :  ",image.format)
print("Mode :  ",image.mode)
print("Size :  ",image.size)
print("Width :  ",image.width)
print("Height :  ",image.height)
image.close()
# Out:
# Filename :   butterfly2.jpg
# Format :   JPEG
# Mode :   RGB
# Size :   (265, 190)
# Width :   265
# Height :   190
